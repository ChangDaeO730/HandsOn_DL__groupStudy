# %% [markdown]
# <a href="https://colab.research.google.com/github/changdaeoh/HandsOn_DL/blob/main/sub_materials/5_GAN_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 구글드라이브와 연동
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## DCGAN
# * 네트워크는 전부 convolutional layer로 구성되며, 판별기의 pooling층(down sampling)은 large stride conv으로 대체, 생성기에서는 transposed conv를 사용

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D, Conv2DTranspose
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam

import matplotlib.pyplot as plt
plt.style.use("seaborn-dark")

import sys

import numpy as np

# %% [markdown]
# conv층에서 1보다 큰 stride에 대해 padding = "same"을 적용시<br/>
# output = (input + pad - kernel)/stride + 1 에서 i + p - k가 s로 나눠떨어지게 하는 최소의 p가 padding size가 됨

# %%
class DCGAN():
    def __init__(self, rows, cols, channels, z = 10):
        # input shape
        self.img_rows = rows
        self.img_cols = cols
        self.channels = channels
        self.img_shape = (self.img_rows, self.img_cols, self.channels)
        self.latent_dim = z

        optimizer = Adam(0.0002, 0.5)

        # 판별기 구축 및 컴파일
        self.discriminator = self.build_discriminator()
        self.discriminator.compile(loss = "binary_crossentropy", optimizer = optimizer,
                                   metrics = ['accuracy'])
        #생성기 구축
        self.generator = self.build_generator()

        ''' functional API로 전체 e2e모델 구축
        위에서 판별기만 따로 compile해주고 생성기는 build만 했는데,
        아래 정의할 combined 모델의 compile이 생성기에 대한 loss, opt 컴파일임.
        '''
        # 생성기 - 노이즈를 입력받아 이미지 생성
        z = Input(shape = (self.latent_dim,))
        img = self.generator(z)
        # 판별기 - 이미지를 입력받아 진위여부 판단
        valid = self.discriminator(img)
        # 결합모델
        self.combined = Model(z, valid)
        self.combined.compile(loss = "binary_crossentropy", optimizer = optimizer)

    # 생성기 정의
    def build_generator(self):
        model = Sequential()

        model.add(Dense(128 * 7 * 7, activation = "relu", input_dim = self.latent_dim)) # 고차원 사영
        model.add(Reshape((7, 7, 128))) # 3차원 텐서로 형상변경

        model.add(UpSampling2D()) # (14, 14, 128)
        model.add(Conv2D(128, kernel_size=3, padding = "same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Activation("relu"))

        model.add(UpSampling2D()) # (28, 28, 128)
        model.add(Conv2D(64, kernel_size = 3, padding = "same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Activation("relu"))

        model.add(Conv2D(self.channels, kernel_size=3, padding="same")) #  원본이미지와 같은 shape
        model.add(Activation("tanh"))

        model.summary()

        # functional API로 generator 반환
        noise = Input(shape = (self.latent_dim, ))
        img = model(noise)

        return Model(noise, img)

    # 판별기 정의
    def build_discriminator(self):
        model = Sequential()

        model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=self.img_shape, padding="same")) 
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.25))

        model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
        model.add(ZeroPadding2D(padding=((0,1),(0,1))))
        model.add(BatchNormalization(momentum=0.8))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.25))

        model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.25))

        model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.25))

        model.add(Flatten())
        model.add(Dense(1, activation='sigmoid'))

        model.summary()

        img = Input(shape=self.img_shape)
        validity = model(img)

        return Model(img, validity)
    
    def train(self, epochs, batch_size = 256, save_interval = 50):

        # Load the dataset
        (X_train, _), (_, _) = mnist.load_data()

        # Rescale -1 to 1
        X_train = X_train / 127.5 - 1.
        X_train = np.expand_dims(X_train, axis = 3) # (b, w, h) -> (b, w, h, c)

        # Adversarial ground truths
        valid = np.ones((batch_size, 1))
        fake = np.zeros((batch_size, 1))

        for epoch in range(epochs):
            # ---------------------
            #  Train Discriminator
            # ---------------------
            
            # batch size개 만큼의 훈련이미지 랜덤샘플링
            idx = np.random.randint(0, X_train.shape[0], batch_size)
            imgs = X_train[idx]

            # 노이즈를 샘플링하여 생성자에 전달 -> 인조 이미지 배치 생성
            noise = np.random.normal(0, 1, (batch_size, self.latent_dim))
            gen_imgs = self.generator.predict(noise)

            # 판별기 훈련(진짜는 1, 가짜는 0)
            d_loss_real = self.discriminator.train_on_batch(imgs, valid)
            d_loss_fake = self.discriminator.train_on_batch(gen_imgs, fake)
            d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) # 평균 loss

            # ---------------------
            #  Train Generator
            # ---------------------

            # 생성이미지에 valid label을 붙여 생성기를 훈련
            g_loss = self.combined.train_on_batch(noise, valid)

            # Plot the progress
            print(f"epoch{epoch} => [loss:{d_loss[0]:.2f}], [acc:{d_loss[1]*100:.2f}], [gen_loss:{g_loss:.2f}]")
            
            if epoch % save_interval == 0:
                self.save_imgs(epoch)
        
    def save_imgs(self, epoch):
        r, c = 5, 5
        noise = np.random.normal(0, 1, (r * c, self.latent_dim))
        gen_imgs = self.generator.predict(noise)

        # Rescale images 0 - 1
        gen_imgs = 0.5 * gen_imgs + 0.5

        fig, axs = plt.subplots(r, c)
        cnt = 0
        for i in range(r):
            for j in range(c):
                axs[i,j].imshow(gen_imgs[cnt, :,:,0], cmap='gray')
                axs[i,j].axis('off')
                cnt += 1
        fig.savefig("./dcgan_mnist_%d.png" % epoch)
        plt.close()

# %%
import os

os.chdir("/content/drive/MyDrive/Colab Notebooks/results")

# %%
dcgan = DCGAN(28,28,1)
dcgan.train(epochs=5000, batch_size=256, save_interval=50)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# epoch0 => [loss:0.99], [acc:38.09], [gen_loss:1.07]
# epoch1 => [loss:0.50], [acc:72.66], [gen_loss:0.63]
# epoch2 => [loss:0.22], [acc:92.97], [gen_loss:0.32]
# epoch3 => [loss:0.11], [acc:98.44], [gen_loss:0.14]
# epoch4 => [loss:0.06], [acc:100.00], [gen_loss:0.04]
# epoch5 => [loss:0.04], [acc:100.00], [gen_loss:0.02]
# epoch6 => [loss:0.04], [acc:99.80], [gen_loss:0.02]
# epoch7 => [loss:0.04], [acc:100.00], [gen_loss:0.01]
# epoch8 => [loss:0.05], [acc:99.61], [gen_loss:0.01]
# epoch9 => [loss:0.06], [acc:99.41], [gen_loss:0.02]
# epoch10 => [loss:0.09], [acc:97.46], [gen_loss:0.02]
# epoch11 => [loss:0.12], [acc:95.70], [gen_loss:0.08]
# epoch12 => [loss:0.19], [acc:91.80], [gen_loss:0.20]
# epoch13 => [loss:0.76], [acc:59.77], [gen_loss:0.62]
# epoch14 => [loss:0.79], [acc:57.23], [gen_loss:0.41]
# epoch15 => [loss:0.56], [acc:69.73], [gen_loss:0.32]
# epoch16 => [loss:0.84], [acc:57.62], [gen_loss:0.41]
# epoch17 => [loss:1.01], [acc:52.15], [gen_loss:0.58]
# epoch18 => [loss:1.22], [acc:46.48], [gen_loss:0.62]
# epoch19 => [loss:1.56], [acc:41.60], [gen_loss:0.61]
# epoch20 => [loss:1.39], [acc:38.28], [gen_loss:0.57]
# epoch21 => [loss:1.28], [acc:40.43], [gen_loss:0.62]
# epoch22 => [loss:1.20], [acc:38.48], [gen_loss:0.69]
# epoch23 => [loss:1.29], [acc:38.28], [gen_loss:0.68]
# epoch24 => [loss:1.22], [acc:40.43], [gen_loss:0.63]
# epoch25 => [loss:1.13], [acc:43.16], [gen_loss:0.53]
# epoch26 => [loss:1.21], [acc:37.70], [gen_loss:0.47]
# epoch27 => [loss:1.38], [acc:30.86], [gen_loss:0.45]
# epoch28 => [loss:1.28], [acc:28.52], [gen_loss:0.45]
# epoch29 => [loss:1.46], [acc:27.73], [gen_loss:0.55]
# epoch30 => [loss:1.49], [acc:29.88], [gen_loss:0.79]
# epoch31 => [loss:1.40], [acc:30.47], [gen_loss:0.88]
# epoch32 => [loss:1.17], [acc:42.19], [gen_loss:0.90]
# epoch33 => [loss:1.17], [acc:42.19], [gen_loss:0.87]
# epoch34 => [loss:1.13], [acc:46.09], [gen_loss:0.82]
# epoch35 => [loss:1.10], [acc:45.90], [gen_loss:0.70]
# epoch36 => [loss:1.03], [acc:47.66], [gen_loss:0.79]
# epoch37 => [loss:1.06], [acc:46.68], [gen_loss:0.68]
# epoch38 => [loss:1.03], [acc:46.09], [gen_loss:0.69]
# epoch39 => [loss:1.02], [acc:46.48], [gen_loss:0.69]
# epoch40 => [loss:1.03], [acc:44.73], [gen_loss:0.61]
# epoch41 => [loss:1.02], [acc:46.88], [gen_loss:0.61]
# epoch42 => [loss:0.90], [acc:48.63], [gen_loss:0.63]
# epoch43 => [loss:0.83], [acc:53.71], [gen_loss:0.56]
# epoch44 => [loss:0.83], [acc:54.69], [gen_loss:0.59]
# epoch45 => [loss:0.86], [acc:51.56], [gen_loss:0.56]
# epoch46 => [loss:0.91], [acc:49.80], [gen_loss:0.52]
# epoch47 => [loss:0.99], [acc:49.61], [gen_loss:0.59]
# epoch48 => [loss:1.10], [acc:44.34], [gen_loss:0.55]
# epoch49 => [loss:1.08], [acc:41.99], [gen_loss:0.60]
# epoch50 => [loss:0.99], [acc:42.38], [gen_loss:0.55]
# epoch51 => [loss:1.01], [acc:42.77], [gen_loss:0.47]
# epoch52 => [loss:0.92], [acc:48.24], [gen_loss:0.50]
# epoch53 => [loss:1.00], [acc:43.55], [gen_loss:0.48]
# epoch54 => [loss:1.01], [acc:43.16], [gen_loss:0.47]
# epoch55 => [loss:1.04], [acc:42.77], [gen_loss:0.53]
# epoch56 => [loss:1.06], [acc:40.43], [gen_loss:0.54]
# epoch57 => [loss:1.07], [acc:39.65], [gen_loss:0.57]
# epoch58 => [loss:1.09], [acc:39.45], [gen_loss:0.59]
# epoch59 => [loss:0.98], [acc:44.14], [gen_loss:0.62]
# epoch60 => [loss:1.00], [acc:45.31], [gen_loss:0.59]
# epoch61 => [loss:1.03], [acc:42.58], [gen_loss:0.55]
# epoch62 => [loss:0.95], [acc:45.70], [gen_loss:0.61]
# epoch63 => [loss:1.04], [acc:40.23], [gen_loss:0.58]
# epoch64 => [loss:1.03], [acc:42.97], [gen_loss:0.63]
# epoch65 => [loss:1.04], [acc:43.55], [gen_loss:0.60]
# epoch66 => [loss:1.03], [acc:40.82], [gen_loss:0.64]
# epoch67 => [loss:1.01], [acc:44.34], [gen_loss:0.60]
# epoch68 => [loss:1.00], [acc:45.31], [gen_loss:0.62]
# epoch69 => [loss:1.03], [acc:41.21], [gen_loss:0.60]
# epoch70 => [loss:0.98], [acc:44.34], [gen_loss:0.63]
# epoch71 => [loss:1.04], [acc:42.19], [gen_loss:0.60]
# epoch72 => [loss:1.00], [acc:43.55], [gen_loss:0.56]
# epoch73 => [loss:0.98], [acc:44.53], [gen_loss:0.59]
# epoch74 => [loss:0.97], [acc:42.77], [gen_loss:0.57]
# epoch75 => [loss:0.99], [acc:45.12], [gen_loss:0.62]
# epoch76 => [loss:1.01], [acc:41.80], [gen_loss:0.57]
# epoch77 => [loss:1.04], [acc:42.77], [gen_loss:0.55]
# epoch78 => [loss:1.03], [acc:46.09], [gen_loss:0.58]
# epoch79 => [loss:0.95], [acc:46.68], [gen_loss:0.53]
# epoch80 => [loss:0.97], [acc:43.55], [gen_loss:0.59]
# epoch81 => [loss:0.98], [acc:44.34], [gen_loss:0.58]
# epoch82 => [loss:0.97], [acc:45.51], [gen_loss:0.61]
# epoch83 => [loss:0.97], [acc:45.90], [gen_loss:0.55]
# epoch84 => [loss:0.98], [acc:44.34], [gen_loss:0.59]
# epoch85 => [loss:0.94], [acc:45.12], [gen_loss:0.54]
# epoch86 => [loss:0.99], [acc:44.53], [gen_loss:0.55]
# epoch87 => [loss:1.00], [acc:41.80], [gen_loss:0.55]
# epoch88 => [loss:0.99], [acc:44.92], [gen_loss:0.56]
# epoch89 => [loss:0.96], [acc:44.34], [gen_loss:0.57]
# epoch90 => [loss:0.93], [acc:46.48], [gen_loss:0.56]
# epoch91 => [loss:0.97], [acc:46.29], [gen_loss:0.55]
# epoch92 => [loss:0.94], [acc:45.70], [gen_loss:0.55]
# epoch93 => [loss:0.98], [acc:42.77], [gen_loss:0.59]
# epoch94 => [loss:0.96], [acc:42.58], [gen_loss:0.55]
# epoch95 => [loss:0.96], [acc:46.29], [gen_loss:0.55]
# epoch96 => [loss:0.91], [acc:45.90], [gen_loss:0.58]
# epoch97 => [loss:0.96], [acc:45.31], [gen_loss:0.52]
# epoch98 => [loss:0.95], [acc:46.09], [gen_loss:0.54]
# epoch99 => [loss:0.93], [acc:46.88], [gen_loss:0.53]
# epoch100 => [loss:0.95], [acc:42.38], [gen_loss:0.52]
# epoch101 => [loss:0.97], [acc:43.75], [gen_loss:0.54]
# epoch102 => [loss:0.95], [acc:43.75], [gen_loss:0.52]
# epoch103 => [loss:0.96], [acc:44.14], [gen_loss:0.53]
# epoch104 => [loss:0.94], [acc:46.09], [gen_loss:0.59]
# epoch105 => [loss:0.95], [acc:42.97], [gen_loss:0.56]
# epoch106 => [loss:0.95], [acc:45.12], [gen_loss:0.52]
# epoch107 => [loss:0.94], [acc:44.73], [gen_loss:0.57]
# epoch108 => [loss:0.92], [acc:46.68], [gen_loss:0.54]
# epoch109 => [loss:0.94], [acc:46.48], [gen_loss:0.52]
# epoch110 => [loss:0.94], [acc:44.92], [gen_loss:0.51]
# epoch111 => [loss:0.93], [acc:43.95], [gen_loss:0.55]
# epoch112 => [loss:0.92], [acc:47.46], [gen_loss:0.56]
# epoch113 => [loss:0.94], [acc:44.14], [gen_loss:0.51]
# epoch114 => [loss:0.95], [acc:43.95], [gen_loss:0.51]
# epoch115 => [loss:0.96], [acc:43.75], [gen_loss:0.54]
# epoch116 => [loss:0.94], [acc:47.07], [gen_loss:0.53]
# epoch117 => [loss:0.91], [acc:46.68], [gen_loss:0.51]
# epoch118 => [loss:0.93], [acc:46.68], [gen_loss:0.53]
# epoch119 => [loss:0.93], [acc:44.34], [gen_loss:0.59]
# epoch120 => [loss:0.95], [acc:43.55], [gen_loss:0.53]
# epoch121 => [loss:0.92], [acc:45.31], [gen_loss:0.54]
# epoch122 => [loss:0.92], [acc:45.51], [gen_loss:0.55]
# epoch123 => [loss:0.93], [acc:45.70], [gen_loss:0.50]
# epoch124 => [loss:0.93], [acc:44.34], [gen_loss:0.54]
# epoch125 => [loss:0.98], [acc:44.73], [gen_loss:0.53]
# epoch126 => [loss:0.95], [acc:44.53], [gen_loss:0.55]
# epoch127 => [loss:0.93], [acc:45.12], [gen_loss:0.54]
# epoch128 => [loss:0.94], [acc:45.70], [gen_loss:0.53]
# epoch129 => [loss:0.91], [acc:46.68], [gen_loss:0.51]
# epoch130 => [loss:0.91], [acc:45.70], [gen_loss:0.54]
# epoch131 => [loss:0.92], [acc:46.09], [gen_loss:0.51]
# epoch132 => [loss:0.94], [acc:46.29], [gen_loss:0.53]
# epoch133 => [loss:0.90], [acc:46.48], [gen_loss:0.52]
# epoch134 => [loss:0.92], [acc:45.90], [gen_loss:0.52]
# epoch135 => [loss:0.90], [acc:44.34], [gen_loss:0.54]
# epoch136 => [loss:0.93], [acc:46.29], [gen_loss:0.49]
# epoch137 => [loss:0.91], [acc:48.44], [gen_loss:0.51]
# epoch138 => [loss:0.95], [acc:44.34], [gen_loss:0.53]
# epoch139 => [loss:0.88], [acc:46.29], [gen_loss:0.54]
# epoch140 => [loss:0.92], [acc:44.53], [gen_loss:0.53]
# epoch141 => [loss:0.94], [acc:45.70], [gen_loss:0.49]
# epoch142 => [loss:0.94], [acc:47.85], [gen_loss:0.53]
# epoch143 => [loss:0.91], [acc:47.07], [gen_loss:0.51]
# epoch144 => [loss:0.91], [acc:44.53], [gen_loss:0.54]
# epoch145 => [loss:0.95], [acc:44.73], [gen_loss:0.52]
# epoch146 => [loss:0.92], [acc:46.68], [gen_loss:0.57]
# epoch147 => [loss:0.91], [acc:43.95], [gen_loss:0.49]
# epoch148 => [loss:0.90], [acc:45.51], [gen_loss:0.50]
# epoch149 => [loss:0.91], [acc:45.90], [gen_loss:0.51]
# epoch150 => [loss:0.91], [acc:47.27], [gen_loss:0.50]
# epoch151 => [loss:0.94], [acc:46.09], [gen_loss:0.49]
# epoch152 => [loss:0.91], [acc:45.12], [gen_loss:0.52]
# epoch153 => [loss:0.94], [acc:44.53], [gen_loss:0.51]
# epoch154 => [loss:0.92], [acc:46.68], [gen_loss:0.52]
# epoch155 => [loss:0.92], [acc:45.51], [gen_loss:0.50]
# epoch156 => [loss:0.94], [acc:43.36], [gen_loss:0.52]
# epoch157 => [loss:0.91], [acc:45.51], [gen_loss:0.50]
# epoch158 => [loss:0.93], [acc:44.92], [gen_loss:0.51]
# epoch159 => [loss:0.92], [acc:46.29], [gen_loss:0.53]
# epoch160 => [loss:0.91], [acc:46.09], [gen_loss:0.51]
# epoch161 => [loss:0.91], [acc:46.09], [gen_loss:0.50]
# epoch162 => [loss:0.90], [acc:46.48], [gen_loss:0.51]
# epoch163 => [loss:0.91], [acc:46.88], [gen_loss:0.52]
# epoch164 => [loss:0.88], [acc:46.48], [gen_loss:0.52]
# epoch165 => [loss:0.89], [acc:46.48], [gen_loss:0.50]
# epoch166 => [loss:0.89], [acc:45.70], [gen_loss:0.52]
# epoch167 => [loss:0.89], [acc:46.68], [gen_loss:0.52]
# epoch168 => [loss:0.92], [acc:45.51], [gen_loss:0.50]
# epoch169 => [loss:0.87], [acc:47.46], [gen_loss:0.50]
# epoch170 => [loss:0.92], [acc:46.09], [gen_loss:0.53]
# epoch171 => [loss:0.93], [acc:46.48], [gen_loss:0.51]
# epoch172 => [loss:0.91], [acc:45.70], [gen_loss:0.47]
# epoch173 => [loss:0.90], [acc:44.73], [gen_loss:0.53]
# epoch174 => [loss:0.91], [acc:45.90], [gen_loss:0.50]
# epoch175 => [loss:0.92], [acc:44.14], [gen_loss:0.52]
# epoch176 => [loss:0.90], [acc:46.68], [gen_loss:0.50]
# epoch177 => [loss:0.93], [acc:43.55], [gen_loss:0.49]
# epoch178 => [loss:0.92], [acc:45.12], [gen_loss:0.50]
# epoch179 => [loss:0.90], [acc:45.31], [gen_loss:0.54]
# epoch180 => [loss:0.92], [acc:45.70], [gen_loss:0.51]
# epoch181 => [loss:0.91], [acc:46.29], [gen_loss:0.48]
# epoch182 => [loss:0.93], [acc:44.34], [gen_loss:0.50]
# epoch183 => [loss:0.92], [acc:44.92], [gen_loss:0.49]
# epoch184 => [loss:0.95], [acc:44.34], [gen_loss:0.51]
# epoch185 => [loss:0.92], [acc:46.88], [gen_loss:0.50]
# epoch186 => [loss:0.89], [acc:46.09], [gen_loss:0.55]
# epoch187 => [loss:0.88], [acc:46.68], [gen_loss:0.46]
# epoch188 => [loss:0.91], [acc:46.48], [gen_loss:0.49]
# epoch189 => [loss:0.90], [acc:44.92], [gen_loss:0.53]
# epoch190 => [loss:0.90], [acc:45.12], [gen_loss:0.52]
# epoch191 => [loss:0.87], [acc:46.68], [gen_loss:0.52]
# epoch192 => [loss:0.93], [acc:43.95], [gen_loss:0.47]
# epoch193 => [loss:0.86], [acc:48.24], [gen_loss:0.51]
# epoch194 => [loss:0.90], [acc:45.90], [gen_loss:0.52]
# epoch195 => [loss:0.92], [acc:44.73], [gen_loss:0.52]
# epoch196 => [loss:0.90], [acc:45.90], [gen_loss:0.52]
# epoch197 => [loss:0.88], [acc:47.66], [gen_loss:0.52]
# epoch198 => [loss:0.91], [acc:47.07], [gen_loss:0.50]
# epoch199 => [loss:0.88], [acc:48.24], [gen_loss:0.56]
# epoch200 => [loss:0.89], [acc:47.85], [gen_loss:0.52]
# epoch201 => [loss:0.92], [acc:46.88], [gen_loss:0.49]
# epoch202 => [loss:0.86], [acc:48.24], [gen_loss:0.51]
# epoch203 => [loss:0.96], [acc:45.31], [gen_loss:0.50]
# epoch204 => [loss:0.94], [acc:44.73], [gen_loss:0.51]
# epoch205 => [loss:0.89], [acc:44.92], [gen_loss:0.51]
# epoch206 => [loss:0.90], [acc:47.85], [gen_loss:0.49]
# epoch207 => [loss:0.92], [acc:48.44], [gen_loss:0.50]
# epoch208 => [loss:0.87], [acc:48.05], [gen_loss:0.52]
# epoch209 => [loss:0.89], [acc:47.66], [gen_loss:0.50]
# epoch210 => [loss:0.88], [acc:47.46], [gen_loss:0.50]
# epoch211 => [loss:0.93], [acc:45.51], [gen_loss:0.51]
# epoch212 => [loss:0.90], [acc:45.70], [gen_loss:0.49]
# epoch213 => [loss:0.90], [acc:49.02], [gen_loss:0.48]
# epoch214 => [loss:0.90], [acc:45.31], [gen_loss:0.50]
# epoch215 => [loss:0.88], [acc:47.27], [gen_loss:0.54]
# epoch216 => [loss:0.91], [acc:45.31], [gen_loss:0.51]
# epoch217 => [loss:0.92], [acc:45.12], [gen_loss:0.49]
# epoch218 => [loss:0.89], [acc:45.51], [gen_loss:0.53]
# epoch219 => [loss:0.92], [acc:44.73], [gen_loss:0.52]
# epoch220 => [loss:0.93], [acc:45.51], [gen_loss:0.51]
# epoch221 => [loss:0.88], [acc:47.07], [gen_loss:0.51]
# epoch222 => [loss:0.89], [acc:46.68], [gen_loss:0.52]
# epoch223 => [loss:0.88], [acc:44.92], [gen_loss:0.49]
# epoch224 => [loss:0.90], [acc:46.48], [gen_loss:0.50]
# epoch225 => [loss:0.89], [acc:46.48], [gen_loss:0.52]
# epoch226 => [loss:0.89], [acc:46.88], [gen_loss:0.50]
# epoch227 => [loss:0.91], [acc:46.09], [gen_loss:0.49]
# epoch228 => [loss:0.88], [acc:47.27], [gen_loss:0.49]
# epoch229 => [loss:0.89], [acc:45.51], [gen_loss:0.48]
# epoch230 => [loss:0.91], [acc:45.31], [gen_loss:0.51]
# epoch231 => [loss:0.90], [acc:45.51], [gen_loss:0.52]
# epoch232 => [loss:0.88], [acc:48.44], [gen_loss:0.51]
# epoch233 => [loss:0.89], [acc:46.09], [gen_loss:0.52]
# epoch234 => [loss:0.88], [acc:44.92], [gen_loss:0.49]
# epoch235 => [loss:0.89], [acc:45.51], [gen_loss:0.50]
# epoch236 => [loss:0.89], [acc:48.63], [gen_loss:0.52]
# epoch237 => [loss:0.91], [acc:46.48], [gen_loss:0.51]
# epoch238 => [loss:0.91], [acc:46.88], [gen_loss:0.51]
# epoch239 => [loss:0.87], [acc:49.02], [gen_loss:0.49]
# epoch240 => [loss:0.88], [acc:46.29], [gen_loss:0.51]
# epoch241 => [loss:0.87], [acc:46.48], [gen_loss:0.47]
# epoch242 => [loss:0.90], [acc:45.70], [gen_loss:0.46]
# epoch243 => [loss:0.85], [acc:48.44], [gen_loss:0.49]
# epoch244 => [loss:0.89], [acc:44.34], [gen_loss:0.49]
# epoch245 => [loss:0.92], [acc:46.88], [gen_loss:0.49]
# epoch246 => [loss:0.95], [acc:44.34], [gen_loss:0.48]
# epoch247 => [loss:0.91], [acc:45.70], [gen_loss:0.51]
# epoch248 => [loss:0.88], [acc:47.27], [gen_loss:0.49]
# epoch249 => [loss:0.89], [acc:45.31], [gen_loss:0.50]
# epoch250 => [loss:0.86], [acc:49.02], [gen_loss:0.50]
# epoch251 => [loss:0.88], [acc:47.66], [gen_loss:0.51]
# epoch252 => [loss:0.85], [acc:47.66], [gen_loss:0.52]
# epoch253 => [loss:0.84], [acc:46.68], [gen_loss:0.50]
# epoch254 => [loss:0.90], [acc:46.68], [gen_loss:0.51]
# epoch255 => [loss:0.88], [acc:48.44], [gen_loss:0.52]
# epoch256 => [loss:0.90], [acc:46.29], [gen_loss:0.49]
# epoch257 => [loss:0.92], [acc:44.92], [gen_loss:0.49]
# epoch258 => [loss:0.88], [acc:45.51], [gen_loss:0.48]
# epoch259 => [loss:0.88], [acc:46.48], [gen_loss:0.48]
# epoch260 => [loss:0.87], [acc:48.63], [gen_loss:0.48]
# epoch261 => [loss:0.87], [acc:46.68], [gen_loss:0.49]
# epoch262 => [loss:0.85], [acc:48.05], [gen_loss:0.49]
# epoch263 => [loss:0.86], [acc:47.66], [gen_loss:0.49]
# epoch264 => [loss:0.88], [acc:46.68], [gen_loss:0.51]
# epoch265 => [loss:0.90], [acc:46.29], [gen_loss:0.51]
# epoch266 => [loss:0.88], [acc:46.09], [gen_loss:0.47]
# epoch267 => [loss:0.88], [acc:48.05], [gen_loss:0.50]
# epoch268 => [loss:0.88], [acc:47.27], [gen_loss:0.52]
# epoch269 => [loss:0.88], [acc:46.48], [gen_loss:0.50]
# epoch270 => [loss:0.87], [acc:47.27], [gen_loss:0.49]
# epoch271 => [loss:0.86], [acc:46.68], [gen_loss:0.50]
# epoch272 => [loss:0.86], [acc:47.66], [gen_loss:0.48]
# epoch273 => [loss:0.89], [acc:45.51], [gen_loss:0.48]
# epoch274 => [loss:0.86], [acc:48.44], [gen_loss:0.48]
# epoch275 => [loss:0.87], [acc:48.24], [gen_loss:0.47]
# epoch276 => [loss:0.88], [acc:45.90], [gen_loss:0.50]
# epoch277 => [loss:0.85], [acc:47.27], [gen_loss:0.50]
# epoch278 => [loss:0.91], [acc:44.92], [gen_loss:0.47]
# epoch279 => [loss:0.91], [acc:45.51], [gen_loss:0.50]
# epoch280 => [loss:0.89], [acc:47.07], [gen_loss:0.48]
# epoch281 => [loss:0.86], [acc:46.29], [gen_loss:0.50]
# epoch282 => [loss:0.85], [acc:48.05], [gen_loss:0.47]
# epoch283 => [loss:0.87], [acc:48.63], [gen_loss:0.47]
# epoch284 => [loss:0.88], [acc:44.92], [gen_loss:0.47]
# epoch285 => [loss:0.87], [acc:48.24], [gen_loss:0.50]
# epoch286 => [loss:0.88], [acc:47.07], [gen_loss:0.52]
# epoch287 => [loss:0.89], [acc:46.29], [gen_loss:0.52]
# epoch288 => [loss:0.87], [acc:47.27], [gen_loss:0.48]
# epoch289 => [loss:0.89], [acc:46.88], [gen_loss:0.47]
# epoch290 => [loss:0.85], [acc:47.46], [gen_loss:0.52]
# epoch291 => [loss:0.86], [acc:47.27], [gen_loss:0.48]
# epoch292 => [loss:0.87], [acc:48.05], [gen_loss:0.50]
# epoch293 => [loss:0.87], [acc:47.46], [gen_loss:0.50]
# epoch294 => [loss:0.92], [acc:46.29], [gen_loss:0.49]
# epoch295 => [loss:0.86], [acc:46.88], [gen_loss:0.50]
# epoch296 => [loss:0.86], [acc:48.63], [gen_loss:0.51]
# epoch297 => [loss:0.87], [acc:46.88], [gen_loss:0.51]
# epoch298 => [loss:0.91], [acc:44.34], [gen_loss:0.50]
# epoch299 => [loss:0.89], [acc:47.07], [gen_loss:0.47]
# epoch300 => [loss:0.86], [acc:48.83], [gen_loss:0.51]
# epoch301 => [loss:0.87], [acc:46.09], [gen_loss:0.50]
# epoch302 => [loss:0.88], [acc:46.29], [gen_loss:0.47]
# epoch303 => [loss:0.87], [acc:46.48], [gen_loss:0.52]
# epoch304 => [loss:0.87], [acc:48.05], [gen_loss:0.50]
# epoch305 => [loss:0.88], [acc:48.83], [gen_loss:0.49]
# epoch306 => [loss:0.85], [acc:49.02], [gen_loss:0.49]
# epoch307 => [loss:0.88], [acc:47.66], [gen_loss:0.47]
# epoch308 => [loss:0.89], [acc:47.07], [gen_loss:0.49]
# epoch309 => [loss:0.87], [acc:47.85], [gen_loss:0.48]
# epoch310 => [loss:0.85], [acc:45.90], [gen_loss:0.48]
# epoch311 => [loss:0.90], [acc:44.92], [gen_loss:0.48]
# epoch312 => [loss:0.88], [acc:47.46], [gen_loss:0.49]
# epoch313 => [loss:0.89], [acc:46.68], [gen_loss:0.48]
# epoch314 => [loss:0.90], [acc:44.14], [gen_loss:0.47]
# epoch315 => [loss:0.87], [acc:45.31], [gen_loss:0.49]
# epoch316 => [loss:0.87], [acc:46.88], [gen_loss:0.49]
# epoch317 => [loss:0.89], [acc:46.68], [gen_loss:0.49]
# epoch318 => [loss:0.85], [acc:49.41], [gen_loss:0.49]
# epoch319 => [loss:0.85], [acc:49.22], [gen_loss:0.51]
# epoch320 => [loss:0.88], [acc:46.88], [gen_loss:0.47]
# epoch321 => [loss:0.88], [acc:45.90], [gen_loss:0.48]
# epoch322 => [loss:0.87], [acc:45.90], [gen_loss:0.50]
# epoch323 => [loss:0.87], [acc:47.46], [gen_loss:0.45]
# epoch324 => [loss:0.89], [acc:47.46], [gen_loss:0.48]
# epoch325 => [loss:0.88], [acc:47.27], [gen_loss:0.52]
# epoch326 => [loss:0.87], [acc:47.46], [gen_loss:0.49]
# epoch327 => [loss:0.82], [acc:48.24], [gen_loss:0.48]
# epoch328 => [loss:0.85], [acc:47.66], [gen_loss:0.45]
# epoch329 => [loss:0.86], [acc:46.48], [gen_loss:0.50]
# epoch330 => [loss:0.88], [acc:45.51], [gen_loss:0.50]
# epoch331 => [loss:0.86], [acc:46.68], [gen_loss:0.47]
# epoch332 => [loss:0.88], [acc:46.09], [gen_loss:0.52]
# epoch333 => [loss:0.88], [acc:47.46], [gen_loss:0.48]
# epoch334 => [loss:0.86], [acc:48.44], [gen_loss:0.48]
# epoch335 => [loss:0.86], [acc:47.66], [gen_loss:0.49]
# epoch336 => [loss:0.87], [acc:48.24], [gen_loss:0.48]
# epoch337 => [loss:0.90], [acc:47.07], [gen_loss:0.50]
# epoch338 => [loss:0.86], [acc:48.44], [gen_loss:0.50]
# epoch339 => [loss:0.86], [acc:47.07], [gen_loss:0.50]
# epoch340 => [loss:0.87], [acc:46.29], [gen_loss:0.50]
# epoch341 => [loss:0.87], [acc:47.27], [gen_loss:0.50]
# epoch342 => [loss:0.87], [acc:45.90], [gen_loss:0.47]
# epoch343 => [loss:0.86], [acc:46.09], [gen_loss:0.50]
# epoch344 => [loss:0.85], [acc:45.90], [gen_loss:0.48]
# epoch345 => [loss:0.88], [acc:46.29], [gen_loss:0.50]
# epoch346 => [loss:0.87], [acc:47.07], [gen_loss:0.47]
# epoch347 => [loss:0.90], [acc:44.92], [gen_loss:0.47]
# epoch348 => [loss:0.86], [acc:48.63], [gen_loss:0.50]
# epoch349 => [loss:0.87], [acc:48.44], [gen_loss:0.48]
# epoch350 => [loss:0.87], [acc:46.88], [gen_loss:0.49]
# epoch351 => [loss:0.87], [acc:47.46], [gen_loss:0.49]
# epoch352 => [loss:0.87], [acc:45.90], [gen_loss:0.49]
# epoch353 => [loss:0.87], [acc:46.68], [gen_loss:0.51]
# epoch354 => [loss:0.87], [acc:46.68], [gen_loss:0.50]
# epoch355 => [loss:0.85], [acc:47.85], [gen_loss:0.47]
# epoch356 => [loss:0.86], [acc:47.07], [gen_loss:0.49]
# epoch357 => [loss:0.86], [acc:47.46], [gen_loss:0.49]
# epoch358 => [loss:0.86], [acc:48.05], [gen_loss:0.50]
# epoch359 => [loss:0.86], [acc:48.83], [gen_loss:0.49]
# epoch360 => [loss:0.86], [acc:48.24], [gen_loss:0.50]
# epoch361 => [loss:0.84], [acc:49.61], [gen_loss:0.50]
# epoch362 => [loss:0.85], [acc:49.22], [gen_loss:0.50]
# epoch363 => [loss:0.88], [acc:45.90], [gen_loss:0.47]
# epoch364 => [loss:0.89], [acc:46.88], [gen_loss:0.51]
# epoch365 => [loss:0.88], [acc:47.07], [gen_loss:0.51]
# epoch366 => [loss:0.87], [acc:47.66], [gen_loss:0.47]
# epoch367 => [loss:0.86], [acc:48.05], [gen_loss:0.49]
# epoch368 => [loss:0.87], [acc:46.68], [gen_loss:0.50]
# epoch369 => [loss:0.87], [acc:46.29], [gen_loss:0.52]
# epoch370 => [loss:0.86], [acc:47.85], [gen_loss:0.47]
# epoch371 => [loss:0.87], [acc:46.68], [gen_loss:0.51]
# epoch372 => [loss:0.86], [acc:46.48], [gen_loss:0.49]
# epoch373 => [loss:0.85], [acc:50.39], [gen_loss:0.49]
# epoch374 => [loss:0.87], [acc:48.05], [gen_loss:0.48]
# epoch375 => [loss:0.86], [acc:48.05], [gen_loss:0.48]
# epoch376 => [loss:0.84], [acc:46.09], [gen_loss:0.51]
# epoch377 => [loss:0.83], [acc:48.83], [gen_loss:0.48]
# epoch378 => [loss:0.84], [acc:47.85], [gen_loss:0.49]
# epoch379 => [loss:0.87], [acc:48.63], [gen_loss:0.48]
# epoch380 => [loss:0.85], [acc:46.48], [gen_loss:0.47]
# epoch381 => [loss:0.87], [acc:47.27], [gen_loss:0.50]
# epoch382 => [loss:0.89], [acc:47.46], [gen_loss:0.49]
# epoch383 => [loss:0.88], [acc:44.92], [gen_loss:0.50]
# epoch384 => [loss:0.86], [acc:47.46], [gen_loss:0.48]
# epoch385 => [loss:0.88], [acc:46.88], [gen_loss:0.48]
# epoch386 => [loss:0.87], [acc:48.83], [gen_loss:0.47]
# epoch387 => [loss:0.87], [acc:47.85], [gen_loss:0.49]
# epoch388 => [loss:0.84], [acc:47.46], [gen_loss:0.52]
# epoch389 => [loss:0.85], [acc:46.29], [gen_loss:0.51]
# epoch390 => [loss:0.85], [acc:47.85], [gen_loss:0.49]
# epoch391 => [loss:0.88], [acc:47.46], [gen_loss:0.48]
# epoch392 => [loss:0.84], [acc:47.66], [gen_loss:0.46]
# epoch393 => [loss:0.86], [acc:50.00], [gen_loss:0.48]
# epoch394 => [loss:0.85], [acc:49.41], [gen_loss:0.50]
# epoch395 => [loss:0.89], [acc:47.27], [gen_loss:0.46]
# epoch396 => [loss:0.87], [acc:49.02], [gen_loss:0.50]
# epoch397 => [loss:0.85], [acc:46.48], [gen_loss:0.48]
# epoch398 => [loss:0.84], [acc:48.24], [gen_loss:0.47]
# epoch399 => [loss:0.85], [acc:48.05], [gen_loss:0.49]
# epoch400 => [loss:0.86], [acc:47.27], [gen_loss:0.46]
# epoch401 => [loss:0.86], [acc:47.66], [gen_loss:0.49]
# epoch402 => [loss:0.83], [acc:47.27], [gen_loss:0.51]
# epoch403 => [loss:0.85], [acc:48.24], [gen_loss:0.50]
# epoch404 => [loss:0.87], [acc:45.90], [gen_loss:0.48]
# epoch405 => [loss:0.86], [acc:48.24], [gen_loss:0.48]
# epoch406 => [loss:0.85], [acc:46.68], [gen_loss:0.49]
# epoch407 => [loss:0.83], [acc:49.22], [gen_loss:0.50]
# epoch408 => [loss:0.87], [acc:46.48], [gen_loss:0.51]
# epoch409 => [loss:0.86], [acc:47.27], [gen_loss:0.48]
# epoch410 => [loss:0.87], [acc:46.09], [gen_loss:0.49]
# epoch411 => [loss:0.87], [acc:47.07], [gen_loss:0.50]
# epoch412 => [loss:0.84], [acc:47.66], [gen_loss:0.50]
# epoch413 => [loss:0.83], [acc:48.05], [gen_loss:0.48]
# epoch414 => [loss:0.87], [acc:47.85], [gen_loss:0.49]
# epoch415 => [loss:0.87], [acc:47.46], [gen_loss:0.48]
# epoch416 => [loss:0.88], [acc:45.12], [gen_loss:0.49]
# epoch417 => [loss:0.87], [acc:46.48], [gen_loss:0.46]
# epoch418 => [loss:0.84], [acc:48.05], [gen_loss:0.48]
# epoch419 => [loss:0.86], [acc:45.31], [gen_loss:0.49]
# epoch420 => [loss:0.87], [acc:47.85], [gen_loss:0.50]
# epoch421 => [loss:0.85], [acc:45.90], [gen_loss:0.47]
# epoch422 => [loss:0.86], [acc:48.44], [gen_loss:0.48]
# epoch423 => [loss:0.86], [acc:46.88], [gen_loss:0.50]
# epoch424 => [loss:0.83], [acc:49.02], [gen_loss:0.48]
# epoch425 => [loss:0.85], [acc:49.02], [gen_loss:0.48]
# epoch426 => [loss:0.86], [acc:48.44], [gen_loss:0.49]
# epoch427 => [loss:0.85], [acc:49.02], [gen_loss:0.47]
# epoch428 => [loss:0.89], [acc:45.90], [gen_loss:0.47]
# epoch429 => [loss:0.86], [acc:47.27], [gen_loss:0.47]
# epoch430 => [loss:0.86], [acc:49.02], [gen_loss:0.48]
# epoch431 => [loss:0.87], [acc:46.48], [gen_loss:0.48]
# epoch432 => [loss:0.85], [acc:48.24], [gen_loss:0.46]
# epoch433 => [loss:0.87], [acc:46.09], [gen_loss:0.47]
# epoch434 => [loss:0.87], [acc:46.68], [gen_loss:0.47]
# epoch435 => [loss:0.84], [acc:47.07], [gen_loss:0.49]
# epoch436 => [loss:0.85], [acc:49.22], [gen_loss:0.50]
# epoch437 => [loss:0.84], [acc:47.85], [gen_loss:0.48]
# epoch438 => [loss:0.85], [acc:48.05], [gen_loss:0.47]
# epoch439 => [loss:0.88], [acc:47.85], [gen_loss:0.46]
# epoch440 => [loss:0.88], [acc:47.27], [gen_loss:0.48]
# epoch441 => [loss:0.85], [acc:48.63], [gen_loss:0.48]
# epoch442 => [loss:0.84], [acc:46.88], [gen_loss:0.48]
# epoch443 => [loss:0.86], [acc:47.46], [gen_loss:0.49]
# epoch444 => [loss:0.87], [acc:48.24], [gen_loss:0.47]
# epoch445 => [loss:0.84], [acc:48.05], [gen_loss:0.48]
# epoch446 => [loss:0.87], [acc:47.46], [gen_loss:0.48]
# epoch447 => [loss:0.86], [acc:48.05], [gen_loss:0.47]
# epoch448 => [loss:0.86], [acc:46.48], [gen_loss:0.48]
# epoch449 => [loss:0.87], [acc:46.29], [gen_loss:0.47]
# epoch450 => [loss:0.86], [acc:48.24], [gen_loss:0.46]
# epoch451 => [loss:0.87], [acc:47.27], [gen_loss:0.49]
# epoch452 => [loss:0.88], [acc:48.24], [gen_loss:0.51]
# epoch453 => [loss:0.86], [acc:47.46], [gen_loss:0.48]
# epoch454 => [loss:0.89], [acc:47.85], [gen_loss:0.47]
# epoch455 => [loss:0.86], [acc:46.09], [gen_loss:0.47]
# epoch456 => [loss:0.84], [acc:48.05], [gen_loss:0.47]
# epoch457 => [loss:0.85], [acc:47.27], [gen_loss:0.47]
# epoch458 => [loss:0.87], [acc:47.46], [gen_loss:0.47]
# epoch459 => [loss:0.85], [acc:48.24], [gen_loss:0.48]
# epoch460 => [loss:0.86], [acc:47.07], [gen_loss:0.47]
# epoch461 => [loss:0.84], [acc:47.27], [gen_loss:0.50]
# epoch462 => [loss:0.85], [acc:47.85], [gen_loss:0.48]
# epoch463 => [loss:0.84], [acc:49.61], [gen_loss:0.46]
# epoch464 => [loss:0.80], [acc:49.41], [gen_loss:0.49]
# epoch465 => [loss:0.83], [acc:50.00], [gen_loss:0.49]
# epoch466 => [loss:0.85], [acc:48.05], [gen_loss:0.47]
# epoch467 => [loss:0.86], [acc:47.07], [gen_loss:0.48]
# epoch468 => [loss:0.83], [acc:48.24], [gen_loss:0.49]
# epoch469 => [loss:0.84], [acc:47.85], [gen_loss:0.52]
# epoch470 => [loss:0.83], [acc:48.44], [gen_loss:0.46]
# epoch471 => [loss:0.84], [acc:48.44], [gen_loss:0.47]
# epoch472 => [loss:0.84], [acc:47.07], [gen_loss:0.48]
# epoch473 => [loss:0.85], [acc:48.63], [gen_loss:0.48]
# epoch474 => [loss:0.86], [acc:46.09], [gen_loss:0.48]
# epoch475 => [loss:0.85], [acc:47.46], [gen_loss:0.45]
# epoch476 => [loss:0.85], [acc:47.85], [gen_loss:0.51]
# epoch477 => [loss:0.86], [acc:47.07], [gen_loss:0.47]
# epoch478 => [loss:0.85], [acc:47.66], [gen_loss:0.50]
# epoch479 => [loss:0.86], [acc:48.24], [gen_loss:0.48]
# epoch480 => [loss:0.84], [acc:47.46], [gen_loss:0.48]
# epoch481 => [loss:0.86], [acc:49.02], [gen_loss:0.49]
# epoch482 => [loss:0.85], [acc:48.44], [gen_loss:0.46]
# epoch483 => [loss:0.82], [acc:48.44], [gen_loss:0.50]
# epoch484 => [loss:0.83], [acc:49.02], [gen_loss:0.47]
# epoch485 => [loss:0.86], [acc:48.44], [gen_loss:0.47]
# epoch486 => [loss:0.86], [acc:48.24], [gen_loss:0.47]
# epoch487 => [loss:0.87], [acc:47.07], [gen_loss:0.51]
# epoch488 => [loss:0.85], [acc:48.24], [gen_loss:0.51]
# epoch489 => [loss:0.85], [acc:47.46], [gen_loss:0.49]
# epoch490 => [loss:0.87], [acc:46.48], [gen_loss:0.50]
# epoch491 => [loss:0.85], [acc:48.05], [gen_loss:0.49]
# epoch492 => [loss:0.88], [acc:45.31], [gen_loss:0.47]
# epoch493 => [loss:0.84], [acc:48.05], [gen_loss:0.49]
# epoch494 => [loss:0.88], [acc:45.12], [gen_loss:0.51]
# epoch495 => [loss:0.85], [acc:48.05], [gen_loss:0.49]
# epoch496 => [loss:0.86], [acc:46.48], [gen_loss:0.47]
# epoch497 => [loss:0.84], [acc:48.63], [gen_loss:0.48]
# epoch498 => [loss:0.85], [acc:49.02], [gen_loss:0.48]
# epoch499 => [loss:0.83], [acc:48.83], [gen_loss:0.50]
# epoch500 => [loss:0.83], [acc:47.85], [gen_loss:0.49]
# epoch501 => [loss:0.83], [acc:47.85], [gen_loss:0.50]
# epoch502 => [loss:0.84], [acc:47.66], [gen_loss:0.46]
# epoch503 => [loss:0.85], [acc:47.07], [gen_loss:0.47]
# epoch504 => [loss:0.82], [acc:50.00], [gen_loss:0.45]
# epoch505 => [loss:0.83], [acc:47.46], [gen_loss:0.49]
# epoch506 => [loss:0.86], [acc:48.63], [gen_loss:0.46]
# epoch507 => [loss:0.82], [acc:49.61], [gen_loss:0.47]
# epoch508 => [loss:0.85], [acc:47.66], [gen_loss:0.50]
# epoch509 => [loss:0.87], [acc:47.46], [gen_loss:0.48]
# epoch510 => [loss:0.87], [acc:46.09], [gen_loss:0.48]
# epoch511 => [loss:0.85], [acc:48.24], [gen_loss:0.45]
# epoch512 => [loss:0.84], [acc:49.41], [gen_loss:0.48]
# epoch513 => [loss:0.84], [acc:47.27], [gen_loss:0.48]
# epoch514 => [loss:0.84], [acc:47.66], [gen_loss:0.48]
# epoch515 => [loss:0.85], [acc:49.22], [gen_loss:0.50]
# epoch516 => [loss:0.84], [acc:47.27], [gen_loss:0.47]
# epoch517 => [loss:0.82], [acc:49.02], [gen_loss:0.46]
# epoch518 => [loss:0.84], [acc:46.88], [gen_loss:0.46]
# epoch519 => [loss:0.83], [acc:47.07], [gen_loss:0.49]
# epoch520 => [loss:0.87], [acc:46.88], [gen_loss:0.49]
# epoch521 => [loss:0.84], [acc:48.24], [gen_loss:0.45]
# epoch522 => [loss:0.83], [acc:47.85], [gen_loss:0.49]
# epoch523 => [loss:0.84], [acc:47.85], [gen_loss:0.48]
# epoch524 => [loss:0.84], [acc:49.61], [gen_loss:0.49]
# epoch525 => [loss:0.86], [acc:48.24], [gen_loss:0.46]
# epoch526 => [loss:0.82], [acc:49.02], [gen_loss:0.49]
# epoch527 => [loss:0.84], [acc:48.44], [gen_loss:0.48]
# epoch528 => [loss:0.87], [acc:48.05], [gen_loss:0.47]
# epoch529 => [loss:0.84], [acc:49.02], [gen_loss:0.49]
# epoch530 => [loss:0.85], [acc:48.05], [gen_loss:0.50]
# epoch531 => [loss:0.83], [acc:48.24], [gen_loss:0.48]
# epoch532 => [loss:0.83], [acc:49.41], [gen_loss:0.48]
# epoch533 => [loss:0.84], [acc:47.46], [gen_loss:0.47]
# epoch534 => [loss:0.83], [acc:47.27], [gen_loss:0.46]
# epoch535 => [loss:0.86], [acc:46.29], [gen_loss:0.50]
# epoch536 => [loss:0.83], [acc:47.07], [gen_loss:0.47]
# epoch537 => [loss:0.84], [acc:49.41], [gen_loss:0.48]
# epoch538 => [loss:0.83], [acc:48.44], [gen_loss:0.47]
# epoch539 => [loss:0.85], [acc:48.83], [gen_loss:0.49]
# epoch540 => [loss:0.83], [acc:48.24], [gen_loss:0.48]
# epoch541 => [loss:0.86], [acc:49.80], [gen_loss:0.48]
# epoch542 => [loss:0.84], [acc:47.46], [gen_loss:0.46]
# epoch543 => [loss:0.85], [acc:48.24], [gen_loss:0.48]
# epoch544 => [loss:0.84], [acc:48.63], [gen_loss:0.46]
# epoch545 => [loss:0.84], [acc:49.80], [gen_loss:0.47]
# epoch546 => [loss:0.86], [acc:45.12], [gen_loss:0.48]
# epoch547 => [loss:0.85], [acc:48.83], [gen_loss:0.46]
# epoch548 => [loss:0.85], [acc:48.83], [gen_loss:0.45]
# epoch549 => [loss:0.86], [acc:47.66], [gen_loss:0.47]
# epoch550 => [loss:0.84], [acc:47.85], [gen_loss:0.48]
# epoch551 => [loss:0.85], [acc:48.05], [gen_loss:0.49]
# epoch552 => [loss:0.85], [acc:47.07], [gen_loss:0.48]
# epoch553 => [loss:0.84], [acc:48.63], [gen_loss:0.48]
# epoch554 => [loss:0.84], [acc:48.63], [gen_loss:0.46]
# epoch555 => [loss:0.84], [acc:49.61], [gen_loss:0.49]
# epoch556 => [loss:0.85], [acc:48.24], [gen_loss:0.47]
# epoch557 => [loss:0.85], [acc:45.90], [gen_loss:0.49]
# epoch558 => [loss:0.84], [acc:49.02], [gen_loss:0.47]
# epoch559 => [loss:0.85], [acc:47.66], [gen_loss:0.49]
# epoch560 => [loss:0.86], [acc:48.05], [gen_loss:0.46]
# epoch561 => [loss:0.83], [acc:49.02], [gen_loss:0.48]
# epoch562 => [loss:0.83], [acc:48.63], [gen_loss:0.49]
# epoch563 => [loss:0.83], [acc:47.66], [gen_loss:0.47]
# epoch564 => [loss:0.82], [acc:49.41], [gen_loss:0.48]
# epoch565 => [loss:0.84], [acc:48.24], [gen_loss:0.47]
# epoch566 => [loss:0.83], [acc:48.24], [gen_loss:0.49]
# epoch567 => [loss:0.85], [acc:47.46], [gen_loss:0.50]
# epoch568 => [loss:0.84], [acc:47.27], [gen_loss:0.47]
# epoch569 => [loss:0.85], [acc:48.05], [gen_loss:0.50]
# epoch570 => [loss:0.84], [acc:48.05], [gen_loss:0.49]
# epoch571 => [loss:0.83], [acc:48.05], [gen_loss:0.45]
# epoch572 => [loss:0.85], [acc:49.41], [gen_loss:0.48]
# epoch573 => [loss:0.87], [acc:48.05], [gen_loss:0.46]
# epoch574 => [loss:0.84], [acc:47.85], [gen_loss:0.45]
# epoch575 => [loss:0.85], [acc:48.24], [gen_loss:0.46]
# epoch576 => [loss:0.85], [acc:49.41], [gen_loss:0.46]
# epoch577 => [loss:0.85], [acc:47.27], [gen_loss:0.49]
# epoch578 => [loss:0.85], [acc:48.83], [gen_loss:0.46]
# epoch579 => [loss:0.82], [acc:48.83], [gen_loss:0.46]
# epoch580 => [loss:0.85], [acc:47.07], [gen_loss:0.47]
# epoch581 => [loss:0.86], [acc:47.27], [gen_loss:0.47]
# epoch582 => [loss:0.85], [acc:46.29], [gen_loss:0.50]
# epoch583 => [loss:0.83], [acc:47.46], [gen_loss:0.49]
# epoch584 => [loss:0.84], [acc:49.61], [gen_loss:0.46]
# epoch585 => [loss:0.83], [acc:50.59], [gen_loss:0.47]
# epoch586 => [loss:0.85], [acc:48.24], [gen_loss:0.49]
# epoch587 => [loss:0.83], [acc:48.44], [gen_loss:0.47]
# epoch588 => [loss:0.85], [acc:47.07], [gen_loss:0.47]
# epoch589 => [loss:0.83], [acc:48.44], [gen_loss:0.43]
# epoch590 => [loss:0.85], [acc:47.27], [gen_loss:0.47]
# epoch591 => [loss:0.86], [acc:47.27], [gen_loss:0.46]
# epoch592 => [loss:0.84], [acc:47.46], [gen_loss:0.48]
# epoch593 => [loss:0.84], [acc:47.66], [gen_loss:0.45]
# epoch594 => [loss:0.84], [acc:46.88], [gen_loss:0.50]
# epoch595 => [loss:0.85], [acc:48.63], [gen_loss:0.48]
# epoch596 => [loss:0.84], [acc:46.88], [gen_loss:0.49]
# epoch597 => [loss:0.84], [acc:47.85], [gen_loss:0.48]
# epoch598 => [loss:0.84], [acc:48.44], [gen_loss:0.47]
# epoch599 => [loss:0.85], [acc:47.66], [gen_loss:0.49]
# epoch600 => [loss:0.83], [acc:50.00], [gen_loss:0.47]
# epoch601 => [loss:0.85], [acc:48.05], [gen_loss:0.50]
# epoch602 => [loss:0.83], [acc:48.83], [gen_loss:0.45]
# epoch603 => [loss:0.84], [acc:47.66], [gen_loss:0.47]
# epoch604 => [loss:0.84], [acc:48.44], [gen_loss:0.48]
# epoch605 => [loss:0.83], [acc:49.61], [gen_loss:0.50]
# epoch606 => [loss:0.85], [acc:46.88], [gen_loss:0.49]
# epoch607 => [loss:0.85], [acc:48.83], [gen_loss:0.48]
# epoch608 => [loss:0.86], [acc:47.66], [gen_loss:0.46]
# epoch609 => [loss:0.84], [acc:47.46], [gen_loss:0.46]
# epoch610 => [loss:0.88], [acc:46.29], [gen_loss:0.46]
# epoch611 => [loss:0.86], [acc:47.07], [gen_loss:0.47]
# epoch612 => [loss:0.84], [acc:49.02], [gen_loss:0.50]
# epoch613 => [loss:0.82], [acc:49.22], [gen_loss:0.49]
# epoch614 => [loss:0.84], [acc:47.66], [gen_loss:0.47]
# epoch615 => [loss:0.83], [acc:50.59], [gen_loss:0.46]
# epoch616 => [loss:0.82], [acc:48.24], [gen_loss:0.47]
# epoch617 => [loss:0.85], [acc:48.24], [gen_loss:0.48]
# epoch618 => [loss:0.84], [acc:49.61], [gen_loss:0.49]
# epoch619 => [loss:0.83], [acc:48.24], [gen_loss:0.47]
# epoch620 => [loss:0.83], [acc:49.80], [gen_loss:0.45]
# epoch621 => [loss:0.82], [acc:48.83], [gen_loss:0.47]
# epoch622 => [loss:0.83], [acc:49.22], [gen_loss:0.46]
# epoch623 => [loss:0.84], [acc:46.48], [gen_loss:0.46]
# epoch624 => [loss:0.83], [acc:49.02], [gen_loss:0.47]
# epoch625 => [loss:0.84], [acc:47.85], [gen_loss:0.49]
# epoch626 => [loss:0.85], [acc:47.66], [gen_loss:0.46]
# epoch627 => [loss:0.82], [acc:49.02], [gen_loss:0.47]
# epoch628 => [loss:0.83], [acc:49.80], [gen_loss:0.47]
# epoch629 => [loss:0.82], [acc:48.24], [gen_loss:0.48]
# epoch630 => [loss:0.84], [acc:48.44], [gen_loss:0.47]
# epoch631 => [loss:0.84], [acc:48.24], [gen_loss:0.46]
# epoch632 => [loss:0.84], [acc:47.85], [gen_loss:0.48]
# epoch633 => [loss:0.87], [acc:45.90], [gen_loss:0.48]
# epoch634 => [loss:0.81], [acc:50.59], [gen_loss:0.47]
# epoch635 => [loss:0.84], [acc:50.20], [gen_loss:0.46]
# epoch636 => [loss:0.86], [acc:47.27], [gen_loss:0.48]
# epoch637 => [loss:0.83], [acc:48.05], [gen_loss:0.48]
# epoch638 => [loss:0.83], [acc:49.41], [gen_loss:0.48]
# epoch639 => [loss:0.83], [acc:48.83], [gen_loss:0.49]
# epoch640 => [loss:0.84], [acc:47.85], [gen_loss:0.48]
# epoch641 => [loss:0.80], [acc:49.41], [gen_loss:0.45]
# epoch642 => [loss:0.82], [acc:48.83], [gen_loss:0.46]
# epoch643 => [loss:0.84], [acc:47.07], [gen_loss:0.48]
# epoch644 => [loss:0.82], [acc:48.83], [gen_loss:0.47]
# epoch645 => [loss:0.86], [acc:47.66], [gen_loss:0.47]
# epoch646 => [loss:0.84], [acc:49.22], [gen_loss:0.47]
# epoch647 => [loss:0.85], [acc:47.46], [gen_loss:0.48]
# epoch648 => [loss:0.84], [acc:50.39], [gen_loss:0.48]
# epoch649 => [loss:0.82], [acc:49.61], [gen_loss:0.46]
# epoch650 => [loss:0.84], [acc:49.22], [gen_loss:0.46]
# epoch651 => [loss:0.83], [acc:50.20], [gen_loss:0.47]
# epoch652 => [loss:0.82], [acc:49.22], [gen_loss:0.48]
# epoch653 => [loss:0.83], [acc:49.41], [gen_loss:0.46]
# epoch654 => [loss:0.83], [acc:47.85], [gen_loss:0.48]
# epoch655 => [loss:0.83], [acc:48.44], [gen_loss:0.46]
# epoch656 => [loss:0.82], [acc:50.00], [gen_loss:0.46]
# epoch657 => [loss:0.82], [acc:49.41], [gen_loss:0.45]
# epoch658 => [loss:0.84], [acc:49.41], [gen_loss:0.48]
# epoch659 => [loss:0.81], [acc:48.63], [gen_loss:0.49]
# epoch660 => [loss:0.84], [acc:48.83], [gen_loss:0.46]
# epoch661 => [loss:0.84], [acc:48.05], [gen_loss:0.47]
# epoch662 => [loss:0.86], [acc:48.44], [gen_loss:0.47]
# epoch663 => [loss:0.85], [acc:48.44], [gen_loss:0.45]
# epoch664 => [loss:0.83], [acc:48.05], [gen_loss:0.49]
# epoch665 => [loss:0.82], [acc:48.44], [gen_loss:0.46]
# epoch666 => [loss:0.82], [acc:49.22], [gen_loss:0.52]
# epoch667 => [loss:0.84], [acc:47.07], [gen_loss:0.48]
# epoch668 => [loss:0.83], [acc:48.44], [gen_loss:0.45]
# epoch669 => [loss:0.83], [acc:47.27], [gen_loss:0.46]
# epoch670 => [loss:0.82], [acc:49.02], [gen_loss:0.47]
# epoch671 => [loss:0.81], [acc:48.83], [gen_loss:0.50]
# epoch672 => [loss:0.84], [acc:48.05], [gen_loss:0.48]
# epoch673 => [loss:0.83], [acc:50.39], [gen_loss:0.49]
# epoch674 => [loss:0.83], [acc:47.85], [gen_loss:0.45]
# epoch675 => [loss:0.85], [acc:49.02], [gen_loss:0.46]
# epoch676 => [loss:0.83], [acc:49.80], [gen_loss:0.46]
# epoch677 => [loss:0.82], [acc:51.17], [gen_loss:0.46]
# epoch678 => [loss:0.85], [acc:46.88], [gen_loss:0.48]
# epoch679 => [loss:0.84], [acc:47.66], [gen_loss:0.45]
# epoch680 => [loss:0.84], [acc:48.05], [gen_loss:0.48]
# epoch681 => [loss:0.83], [acc:50.20], [gen_loss:0.45]
# epoch682 => [loss:0.82], [acc:49.02], [gen_loss:0.46]
# epoch683 => [loss:0.84], [acc:49.22], [gen_loss:0.47]
# epoch684 => [loss:0.84], [acc:48.24], [gen_loss:0.47]
# epoch685 => [loss:0.83], [acc:48.24], [gen_loss:0.46]
# epoch686 => [loss:0.83], [acc:49.80], [gen_loss:0.45]
# epoch687 => [loss:0.85], [acc:48.63], [gen_loss:0.47]
# epoch688 => [loss:0.83], [acc:48.63], [gen_loss:0.46]
# epoch689 => [loss:0.84], [acc:47.27], [gen_loss:0.47]
# epoch690 => [loss:0.83], [acc:47.85], [gen_loss:0.46]
# epoch691 => [loss:0.83], [acc:49.02], [gen_loss:0.46]
# epoch692 => [loss:0.83], [acc:49.41], [gen_loss:0.46]
# epoch693 => [loss:0.81], [acc:50.98], [gen_loss:0.45]
# epoch694 => [loss:0.83], [acc:48.83], [gen_loss:0.46]
# epoch695 => [loss:0.78], [acc:51.37], [gen_loss:0.48]
# epoch696 => [loss:0.82], [acc:49.22], [gen_loss:0.46]
# epoch697 => [loss:0.85], [acc:49.22], [gen_loss:0.46]
# epoch698 => [loss:0.85], [acc:48.05], [gen_loss:0.44]
# epoch699 => [loss:0.83], [acc:49.02], [gen_loss:0.46]
# epoch700 => [loss:0.82], [acc:49.22], [gen_loss:0.47]
# epoch701 => [loss:0.83], [acc:49.41], [gen_loss:0.45]
# epoch702 => [loss:0.83], [acc:47.27], [gen_loss:0.47]
# epoch703 => [loss:0.84], [acc:48.05], [gen_loss:0.46]
# epoch704 => [loss:0.82], [acc:47.85], [gen_loss:0.46]
# epoch705 => [loss:0.81], [acc:50.39], [gen_loss:0.48]
# epoch706 => [loss:0.82], [acc:48.24], [gen_loss:0.47]
# epoch707 => [loss:0.83], [acc:49.61], [gen_loss:0.46]
# epoch708 => [loss:0.82], [acc:49.02], [gen_loss:0.45]
# epoch709 => [loss:0.83], [acc:48.05], [gen_loss:0.47]
# epoch710 => [loss:0.85], [acc:50.20], [gen_loss:0.46]
# epoch711 => [loss:0.84], [acc:48.05], [gen_loss:0.47]
# epoch712 => [loss:0.81], [acc:49.41], [gen_loss:0.46]
# epoch713 => [loss:0.84], [acc:48.83], [gen_loss:0.46]
# epoch714 => [loss:0.83], [acc:48.05], [gen_loss:0.49]
# epoch715 => [loss:0.85], [acc:49.02], [gen_loss:0.47]
# epoch716 => [loss:0.86], [acc:48.83], [gen_loss:0.45]
# epoch717 => [loss:0.83], [acc:47.66], [gen_loss:0.46]
# epoch718 => [loss:0.81], [acc:48.63], [gen_loss:0.47]
# epoch719 => [loss:0.81], [acc:48.24], [gen_loss:0.48]
# epoch720 => [loss:0.83], [acc:47.46], [gen_loss:0.47]
# epoch721 => [loss:0.81], [acc:48.63], [gen_loss:0.47]
# epoch722 => [loss:0.83], [acc:50.00], [gen_loss:0.47]
# epoch723 => [loss:0.82], [acc:49.22], [gen_loss:0.46]
# epoch724 => [loss:0.85], [acc:48.05], [gen_loss:0.48]
# epoch725 => [loss:0.83], [acc:49.80], [gen_loss:0.47]
# epoch726 => [loss:0.84], [acc:47.66], [gen_loss:0.44]
# epoch727 => [loss:0.82], [acc:48.24], [gen_loss:0.47]
# epoch728 => [loss:0.83], [acc:47.66], [gen_loss:0.50]
# epoch729 => [loss:0.84], [acc:47.66], [gen_loss:0.47]
# epoch730 => [loss:0.84], [acc:47.85], [gen_loss:0.46]
# epoch731 => [loss:0.83], [acc:47.85], [gen_loss:0.47]
# epoch732 => [loss:0.82], [acc:48.83], [gen_loss:0.47]
# epoch733 => [loss:0.82], [acc:48.83], [gen_loss:0.45]
# epoch734 => [loss:0.82], [acc:49.80], [gen_loss:0.46]
# epoch735 => [loss:0.82], [acc:47.27], [gen_loss:0.47]
# epoch736 => [loss:0.83], [acc:48.63], [gen_loss:0.46]
# epoch737 => [loss:0.82], [acc:47.46], [gen_loss:0.47]
# epoch738 => [loss:0.85], [acc:46.48], [gen_loss:0.47]
# epoch739 => [loss:0.85], [acc:47.46], [gen_loss:0.44]
# epoch740 => [loss:0.82], [acc:50.00], [gen_loss:0.47]
# epoch741 => [loss:0.85], [acc:48.63], [gen_loss:0.44]
# epoch742 => [loss:0.81], [acc:49.61], [gen_loss:0.47]
# epoch743 => [loss:0.82], [acc:47.27], [gen_loss:0.47]
# epoch744 => [loss:0.82], [acc:47.27], [gen_loss:0.47]
# epoch745 => [loss:0.82], [acc:48.44], [gen_loss:0.45]
# epoch746 => [loss:0.83], [acc:49.41], [gen_loss:0.47]
# epoch747 => [loss:0.81], [acc:51.17], [gen_loss:0.46]
# epoch748 => [loss:0.81], [acc:49.02], [gen_loss:0.46]
# epoch749 => [loss:0.85], [acc:47.27], [gen_loss:0.48]
# epoch750 => [loss:0.82], [acc:49.02], [gen_loss:0.46]
# epoch751 => [loss:0.84], [acc:47.07], [gen_loss:0.47]
# epoch752 => [loss:0.82], [acc:49.02], [gen_loss:0.46]
# epoch753 => [loss:0.84], [acc:48.05], [gen_loss:0.44]
# epoch754 => [loss:0.84], [acc:48.44], [gen_loss:0.46]
# epoch755 => [loss:0.85], [acc:47.66], [gen_loss:0.45]
# epoch756 => [loss:0.85], [acc:46.88], [gen_loss:0.45]
# epoch757 => [loss:0.84], [acc:49.02], [gen_loss:0.50]
# epoch758 => [loss:0.84], [acc:48.05], [gen_loss:0.45]
# epoch759 => [loss:0.82], [acc:48.63], [gen_loss:0.47]
# epoch760 => [loss:0.82], [acc:50.59], [gen_loss:0.47]
# epoch761 => [loss:0.83], [acc:47.66], [gen_loss:0.47]
# epoch762 => [loss:0.79], [acc:50.59], [gen_loss:0.47]
# epoch763 => [loss:0.81], [acc:49.02], [gen_loss:0.48]
# epoch764 => [loss:0.81], [acc:49.41], [gen_loss:0.46]
# epoch765 => [loss:0.82], [acc:49.02], [gen_loss:0.47]
# epoch766 => [loss:0.83], [acc:47.66], [gen_loss:0.48]
# epoch767 => [loss:0.82], [acc:48.05], [gen_loss:0.48]
# epoch768 => [loss:0.85], [acc:47.66], [gen_loss:0.46]
# epoch769 => [loss:0.82], [acc:47.46], [gen_loss:0.46]
# epoch770 => [loss:0.84], [acc:49.02], [gen_loss:0.45]
# epoch771 => [loss:0.84], [acc:47.46], [gen_loss:0.48]
# epoch772 => [loss:0.82], [acc:49.02], [gen_loss:0.46]
# epoch773 => [loss:0.85], [acc:48.05], [gen_loss:0.45]
# epoch774 => [loss:0.85], [acc:48.24], [gen_loss:0.48]
# epoch775 => [loss:0.84], [acc:48.44], [gen_loss:0.46]
# epoch776 => [loss:0.82], [acc:46.09], [gen_loss:0.49]
# epoch777 => [loss:0.85], [acc:47.66], [gen_loss:0.47]
# epoch778 => [loss:0.83], [acc:48.24], [gen_loss:0.47]
# epoch779 => [loss:0.82], [acc:49.02], [gen_loss:0.47]
# epoch780 => [loss:0.83], [acc:48.83], [gen_loss:0.46]
# epoch781 => [loss:0.81], [acc:49.61], [gen_loss:0.48]
# epoch782 => [loss:0.82], [acc:48.44], [gen_loss:0.45]
# epoch783 => [loss:0.82], [acc:47.46], [gen_loss:0.47]
# epoch784 => [loss:0.84], [acc:49.22], [gen_loss:0.47]
# epoch785 => [loss:0.82], [acc:48.63], [gen_loss:0.47]
# epoch786 => [loss:0.84], [acc:49.41], [gen_loss:0.46]
# epoch787 => [loss:0.82], [acc:49.80], [gen_loss:0.47]
# epoch788 => [loss:0.82], [acc:49.22], [gen_loss:0.46]
# epoch789 => [loss:0.83], [acc:49.22], [gen_loss:0.48]
# epoch790 => [loss:0.82], [acc:49.41], [gen_loss:0.48]
# epoch791 => [loss:0.85], [acc:47.85], [gen_loss:0.47]
# epoch792 => [loss:0.83], [acc:49.22], [gen_loss:0.45]
# epoch793 => [loss:0.83], [acc:47.66], [gen_loss:0.49]
# epoch794 => [loss:0.85], [acc:49.02], [gen_loss:0.46]
# epoch795 => [loss:0.82], [acc:47.66], [gen_loss:0.46]
# epoch796 => [loss:0.82], [acc:47.27], [gen_loss:0.47]
# epoch797 => [loss:0.82], [acc:48.83], [gen_loss:0.46]
# epoch798 => [loss:0.83], [acc:49.02], [gen_loss:0.48]
# epoch799 => [loss:0.83], [acc:49.22], [gen_loss:0.46]
# epoch800 => [loss:0.83], [acc:48.83], [gen_loss:0.45]
# epoch801 => [loss:0.83], [acc:48.44], [gen_loss:0.49]
# epoch802 => [loss:0.82], [acc:47.85], [gen_loss:0.47]
# epoch803 => [loss:0.83], [acc:48.05], [gen_loss:0.47]
# epoch804 => [loss:0.86], [acc:46.48], [gen_loss:0.45]
# epoch805 => [loss:0.81], [acc:49.61], [gen_loss:0.47]
# epoch806 => [loss:0.85], [acc:47.46], [gen_loss:0.45]
# epoch807 => [loss:0.83], [acc:49.22], [gen_loss:0.47]
# epoch808 => [loss:0.82], [acc:48.83], [gen_loss:0.47]
# epoch809 => [loss:0.84], [acc:47.27], [gen_loss:0.44]
# epoch810 => [loss:0.82], [acc:47.07], [gen_loss:0.46]
# epoch811 => [loss:0.84], [acc:47.66], [gen_loss:0.44]
# epoch812 => [loss:0.83], [acc:49.02], [gen_loss:0.46]
# epoch813 => [loss:0.85], [acc:49.02], [gen_loss:0.46]
# epoch814 => [loss:0.82], [acc:49.41], [gen_loss:0.47]
# epoch815 => [loss:0.83], [acc:48.24], [gen_loss:0.45]
# epoch816 => [loss:0.83], [acc:49.80], [gen_loss:0.47]
# epoch817 => [loss:0.83], [acc:48.24], [gen_loss:0.46]
# epoch818 => [loss:0.84], [acc:48.63], [gen_loss:0.46]
# epoch819 => [loss:0.83], [acc:48.24], [gen_loss:0.48]
# epoch820 => [loss:0.82], [acc:49.41], [gen_loss:0.48]
# epoch821 => [loss:0.82], [acc:49.80], [gen_loss:0.48]
# epoch822 => [loss:0.84], [acc:47.27], [gen_loss:0.44]
# epoch823 => [loss:0.85], [acc:48.24], [gen_loss:0.46]
# epoch824 => [loss:0.83], [acc:47.85], [gen_loss:0.47]
# epoch825 => [loss:0.83], [acc:47.07], [gen_loss:0.47]
# epoch826 => [loss:0.81], [acc:49.02], [gen_loss:0.46]
# epoch827 => [loss:0.82], [acc:48.63], [gen_loss:0.46]
# epoch828 => [loss:0.86], [acc:47.66], [gen_loss:0.47]
# epoch829 => [loss:0.82], [acc:47.66], [gen_loss:0.48]
# epoch830 => [loss:0.82], [acc:49.61], [gen_loss:0.47]
# epoch831 => [loss:0.84], [acc:47.66], [gen_loss:0.46]
# epoch832 => [loss:0.80], [acc:50.20], [gen_loss:0.45]
# epoch833 => [loss:0.81], [acc:50.00], [gen_loss:0.46]
# epoch834 => [loss:0.83], [acc:48.63], [gen_loss:0.46]
# epoch835 => [loss:0.82], [acc:48.83], [gen_loss:0.45]
# epoch836 => [loss:0.85], [acc:46.88], [gen_loss:0.45]
# epoch837 => [loss:0.82], [acc:49.02], [gen_loss:0.46]
# epoch838 => [loss:0.82], [acc:49.41], [gen_loss:0.48]
# epoch839 => [loss:0.82], [acc:47.27], [gen_loss:0.46]
# epoch840 => [loss:0.83], [acc:48.24], [gen_loss:0.45]
# epoch841 => [loss:0.82], [acc:48.24], [gen_loss:0.46]
# epoch842 => [loss:0.82], [acc:49.22], [gen_loss:0.45]
# epoch843 => [loss:0.83], [acc:49.80], [gen_loss:0.48]
# epoch844 => [loss:0.83], [acc:47.46], [gen_loss:0.46]
# epoch845 => [loss:0.82], [acc:48.44], [gen_loss:0.46]
# epoch846 => [loss:0.82], [acc:48.83], [gen_loss:0.49]
# epoch847 => [loss:0.84], [acc:48.44], [gen_loss:0.46]
# epoch848 => [loss:0.84], [acc:48.05], [gen_loss:0.46]
# epoch849 => [loss:0.83], [acc:49.41], [gen_loss:0.44]
# epoch850 => [loss:0.83], [acc:48.44], [gen_loss:0.46]
# epoch851 => [loss:0.83], [acc:49.80], [gen_loss:0.48]
# epoch852 => [loss:0.82], [acc:48.24], [gen_loss:0.46]
# epoch853 => [loss:0.82], [acc:48.83], [gen_loss:0.46]
# epoch854 => [loss:0.83], [acc:46.68], [gen_loss:0.45]
# epoch855 => [loss:0.81], [acc:48.83], [gen_loss:0.47]
# epoch856 => [loss:0.82], [acc:48.63], [gen_loss:0.47]
# epoch857 => [loss:0.83], [acc:47.27], [gen_loss:0.46]
# epoch858 => [loss:0.83], [acc:48.24], [gen_loss:0.46]
# epoch859 => [loss:0.84], [acc:47.46], [gen_loss:0.46]
# epoch860 => [loss:0.83], [acc:48.83], [gen_loss:0.48]
# epoch861 => [loss:0.82], [acc:48.24], [gen_loss:0.47]
# epoch862 => [loss:0.82], [acc:47.66], [gen_loss:0.45]
# epoch863 => [loss:0.85], [acc:47.66], [gen_loss:0.47]
# epoch864 => [loss:0.83], [acc:49.41], [gen_loss:0.44]
# epoch865 => [loss:0.82], [acc:47.66], [gen_loss:0.47]
# epoch866 => [loss:0.81], [acc:49.02], [gen_loss:0.45]
# epoch867 => [loss:0.84], [acc:48.24], [gen_loss:0.46]
# epoch868 => [loss:0.83], [acc:48.63], [gen_loss:0.46]
# epoch869 => [loss:0.80], [acc:48.05], [gen_loss:0.46]
# epoch870 => [loss:0.82], [acc:48.44], [gen_loss:0.45]
# epoch871 => [loss:0.84], [acc:48.44], [gen_loss:0.46]
# epoch872 => [loss:0.82], [acc:47.27], [gen_loss:0.47]
# epoch873 => [loss:0.83], [acc:48.05], [gen_loss:0.48]
# epoch874 => [loss:0.83], [acc:48.63], [gen_loss:0.46]
# epoch875 => [loss:0.83], [acc:47.85], [gen_loss:0.45]
# epoch876 => [loss:0.83], [acc:48.24], [gen_loss:0.47]
# epoch877 => [loss:0.81], [acc:48.24], [gen_loss:0.46]
# epoch878 => [loss:0.82], [acc:50.39], [gen_loss:0.45]
# epoch879 => [loss:0.81], [acc:49.41], [gen_loss:0.46]
# epoch880 => [loss:0.82], [acc:49.02], [gen_loss:0.46]
# epoch881 => [loss:0.82], [acc:50.20], [gen_loss:0.47]
# epoch882 => [loss:0.82], [acc:47.66], [gen_loss:0.45]
# epoch883 => [loss:0.84], [acc:49.02], [gen_loss:0.46]
# epoch884 => [loss:0.82], [acc:47.27], [gen_loss:0.47]
# epoch885 => [loss:0.82], [acc:49.02], [gen_loss:0.44]
# epoch886 => [loss:0.83], [acc:48.24], [gen_loss:0.46]
# epoch887 => [loss:0.83], [acc:49.61], [gen_loss:0.46]
# epoch888 => [loss:0.81], [acc:48.83], [gen_loss:0.45]
# epoch889 => [loss:0.79], [acc:50.39], [gen_loss:0.45]
# ...
# epoch4710 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4711 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4712 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4713 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4714 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4715 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4716 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4717 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4718 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4719 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4720 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4721 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4722 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4723 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4724 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4725 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4726 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4727 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4728 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4729 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4730 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4731 => [loss:0.77], [acc:50.00], [gen_loss:0.43]
# epoch4732 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4733 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4734 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4735 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4736 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4737 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4738 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4739 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4740 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4741 => [loss:0.77], [acc:50.20], [gen_loss:0.42]
# epoch4742 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4743 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4744 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4745 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4746 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4747 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4748 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4749 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4750 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4751 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4752 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4753 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4754 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4755 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4756 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4757 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4758 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4759 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4760 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4761 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4762 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4763 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4764 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4765 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4766 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4767 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4768 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4769 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4770 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4771 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4772 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4773 => [loss:0.77], [acc:50.00], [gen_loss:0.43]
# epoch4774 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4775 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4776 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4777 => [loss:0.77], [acc:50.00], [gen_loss:0.43]
# epoch4778 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4779 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4780 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4781 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4782 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4783 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4784 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4785 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4786 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4787 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4788 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4789 => [loss:0.77], [acc:50.00], [gen_loss:0.41]
# epoch4790 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4791 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4792 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4793 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4794 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4795 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4796 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4797 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4798 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4799 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4800 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4801 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4802 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4803 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4804 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4805 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4806 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4807 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4808 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4809 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4810 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4811 => [loss:0.77], [acc:50.00], [gen_loss:0.41]
# epoch4812 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4813 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4814 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4815 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4816 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4817 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4818 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4819 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4820 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4821 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4822 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4823 => [loss:0.77], [acc:50.00], [gen_loss:0.43]
# epoch4824 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4825 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4826 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4827 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4828 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4829 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4830 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4831 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4832 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4833 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4834 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4835 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4836 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4837 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4838 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4839 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4840 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4841 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4842 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4843 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4844 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4845 => [loss:0.77], [acc:50.00], [gen_loss:0.43]
# epoch4846 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4847 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4848 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4849 => [loss:0.77], [acc:50.00], [gen_loss:0.43]
# epoch4850 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4851 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4852 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4853 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4854 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4855 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4856 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4857 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4858 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4859 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4860 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4861 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4862 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4863 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4864 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4865 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4866 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4867 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4868 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4869 => [loss:0.77], [acc:50.00], [gen_loss:0.43]
# epoch4870 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4871 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4872 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4873 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4874 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4875 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4876 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4877 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4878 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4879 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4880 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4881 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4882 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4883 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4884 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4885 => [loss:0.77], [acc:50.00], [gen_loss:0.41]
# epoch4886 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4887 => [loss:0.76], [acc:50.00], [gen_loss:0.41]
# epoch4888 => [loss:0.77], [acc:50.00], [gen_loss:0.41]
# epoch4889 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4890 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4891 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4892 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4893 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4894 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4895 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4896 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4897 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4898 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4899 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4900 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4901 => [loss:0.76], [acc:50.00], [gen_loss:0.41]
# epoch4902 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4903 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4904 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4905 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4906 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4907 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4908 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4909 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4910 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4911 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4912 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4913 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4914 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4915 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4916 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4917 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4918 => [loss:0.77], [acc:50.00], [gen_loss:0.43]
# epoch4919 => [loss:0.77], [acc:50.00], [gen_loss:0.41]
# epoch4920 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4921 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4922 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4923 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4924 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4925 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4926 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4927 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4928 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4929 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4930 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4931 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4932 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4933 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4934 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4935 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4936 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4937 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4938 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4939 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4940 => [loss:0.77], [acc:50.00], [gen_loss:0.43]
# epoch4941 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4942 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4943 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4944 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4945 => [loss:0.76], [acc:50.00], [gen_loss:0.41]
# epoch4946 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4947 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4948 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4949 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4950 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4951 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4952 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4953 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4954 => [loss:0.77], [acc:50.00], [gen_loss:0.43]
# epoch4955 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4956 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4957 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4958 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4959 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4960 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4961 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4962 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4963 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4964 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4965 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4966 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4967 => [loss:0.77], [acc:50.00], [gen_loss:0.41]
# epoch4968 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4969 => [loss:0.77], [acc:50.00], [gen_loss:0.41]
# epoch4970 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4971 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4972 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4973 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4974 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4975 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4976 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4977 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4978 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4979 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4980 => [loss:0.76], [acc:50.00], [gen_loss:0.43]
# epoch4981 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4982 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4983 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4984 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4985 => [loss:0.77], [acc:50.00], [gen_loss:0.41]
# epoch4986 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4987 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4988 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4989 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4990 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4991 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4992 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4993 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4994 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4995 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4996 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4997 => [loss:0.76], [acc:50.00], [gen_loss:0.42]
# epoch4998 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
# epoch4999 => [loss:0.77], [acc:50.00], [gen_loss:0.42]
